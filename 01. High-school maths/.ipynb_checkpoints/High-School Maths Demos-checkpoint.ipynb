# %% [markdown]
# # High-School Maths Demos
# ## Live Demos

# %%
1 + 2
# Out:
# 3

# %%
print("Hallo High-School Maths")
# Out:
# Hallo High-School Maths

# %%
def fib(n):
    a = 0
    b = 1
    if n == 1:
        print(a)
    else:
        print(a)
        print(b)
        for i in range(2,n):
            c = a + b
            a = b
            b = c
            print(c)
fib(5)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
a = 5

# %%
print(a)
# Out:
# 5
